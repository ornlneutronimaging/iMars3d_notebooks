# %% [markdown]
# [![Notebook Tutorial](__code/__all/notebook_tutorial.png)](https://neutronimaging.ornl.gov/ct-reconstruction/)
#
# <img src='__docs/notebook_rules.png' />

# %%
import warnings
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt
# %matplotlib notebook

import imars3d
print(f"Using imarsd version {imars3d.__version__}")

from __code.imars3dui_skipped_algorithms import Imars3dui
from __code.roi_selection_ui import Interface

from __code import system
system.System.select_working_dir()
from __code.__all import custom_style
custom_style.style()
# Out:
# Using imarsd version 1.1.0.dev2
# <style type="text/css">
# .jupyter-widgets select option {font-family: "Lucida Console", Monaco, monospace;}
# .jupyter-widgets select {width: 98%;}
# div.output_subarea {padding: 0px;}
# div.output_subarea > div {margin: 0.4em;}
# </style>
# <style type="text/css">
# .jupyter-widgets select option {font-family: "Lucida Console", Monaco, monospace;}
# div.output_subarea {padding: 0px;}
# div.output_subarea > div {margin: 0.4em;}
# </style>
# ** Using Debugging Mode! **
#                    <style>
#                    .result_label {
#                       font-style: bold;
#                       color: red;
#                       font-size: 18px;
#                    }
#                    </style>
# VBox(children=(HBox(children=(Label(value='Select Instrument', layout=Layout(width='20%')), Select(layout=Layo…
# <style>
#
# /* The following CSS has been adapted from
#    http://nbviewer.ipython.org/github/ketch/teaching-numerics-with-notebooks/blob/master/Styling_notebooks.ipynb
#    by Aron Ahmadia and David Ketcheson and has been reused under CC BY 4.0
#    */
#
# /* main background */
# #site {
#     background: #888;
#     color: #red;
# }
#
# div.container {
#     width: 100% ! important;
# }
#
# div.cell { /* set cell width to about 80 chars */
#     width: 95%;
# }
#
# div #notebook { /* centre the content */
# /*    background: #fff; /* white background for content */
#     background: blue;
#     width: 100%;
#     margin: auto;
#     padding-left: 1em;
#     padding-right: 1em;
#     background-image: url("tile_background.jpg");
# }
#
# #notebook li { /* More space between bullet points */
#     margin-top:0.4em;
# }
#
# /* change background color of running cells */
# div.cell.code_cell.running {
# /*    background-color: rgba(164,188,194,.75); */
#     background-color: green;
#     border-width: 8px
#     border-style: solid
#     border-color: #111;
# }
#
# /* Put a solid color box around each cell and its output, visually linking them together */
# div.cell.code_cell {
#     background-color: rgba(164,188,194,.25); /* Continuum L Gray with alpha 0.25 */
#     border-radius: 10px; /* rounded borders */
#     padding: 1em;
#     margin-top: 1em;
# }
#
# div.text_cell_render{
# 	font-family: Georgia, Times, 'Times New Roman', serif;
#     line-height: 110%;
#     font-size: 105%;
#     width: 95%;
#     margin-left: auto;
#     margin-right: auto;
# }
#
#
# /* Formatting for header cells */
# .text_cell_render h1 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     font-weight: 400;
#     font-size: 30pt;
#     line-height: 100%;
#     color: rgb(37,55,70); /* Continuum Blue*/
#     margin-bottom: 0.1em;
#     margin-top: 0.1em;
#     display: block;
# }
# .text_cell_render h2 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     font-weight: 700;
#     font-size: 22pt;
#     line-height: 100%;
#     color: rgb(37,55,70);
#     margin-bottom: 0.1em;
#     margin-top: 0.1em;
#     display: block;
# }
#
# .text_cell_render h3 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     margin-top:12px;
#     margin-bottom: 3px;
#     font-style: italic;
#     color: rgb(37, 55, 70);
# }
#
# .text_cell_render h4 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
# }
#
# .text_cell_render h5 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     font-weight: 300;
#     font-size: 14pt;
#     font-style: italic;
#     margin-bottom: .1em;
#     margin-top: 0.1em;
#     display: block;
# }
#
# .text_cell_render h6 {
# 	font-family: Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     font-weight: 300;
#     font-size: 10pt;
#     margin-bottom: 1px;
#     margin-top: 1px;
# }
#
# .CodeMirror{
#         font-family: "PT Mono", fixed;
#         font-size: 100%;
# }
#
# #notebook_panel { /* main background */
#     background-image: url("tile_background.jpg");
# }
#
#
#
#
# </style>

# %%
# %gui qt

# %% [markdown]
# # Select input data - MANDATORY

# %% [markdown]
# ## raw data

# %%
o_imars3dui = Imars3dui(working_dir=system.System.get_working_dir())
o_imars3dui.select_raw()
# Out:
# VBox(children=(Label(value='Select Folder of raw', layout=Layout(width='250px')), VBox(children=(HBox(children…
# raw folder selected: ['/Volumes/JeanHardDrive/HFIR/CG1D/IPTS-31148/raw/ct_scans/December3_2022_light'] with 14 files)

# %% [markdown]
# ## ob

# %%
o_imars3dui.select_ob()
# Out:
# VBox(children=(Label(value='Select Folder of ob', layout=Layout(width='250px')), VBox(children=(HBox(children=…
# ob folder selected: ['/Volumes/JeanHardDrive/HFIR/CG1D/IPTS-31148/raw/ob/December3_2022'] with 20 files)

# %% [markdown]
# ## dc

# %%
o_imars3dui.select_dc()
# Out:
# VBox(children=(Label(value='Select Folder of dc', layout=Layout(width='250px')), VBox(children=(HBox(children=…
# dc folder selected: ['/Volumes/JeanHardDrive/HFIR/CG1D/IPTS-31148/raw/dc/2022_12_05'] with 10 files)

# %% [markdown]
# ## Load

# %%
o_imars3dui.load_and_display_data()
# Out:
# ct:   0%|          | 0/14 [00:00<?, ?it/s]
# ob:   0%|          | 0/20 [00:00<?, ?it/s]
# dc:   0%|          | 0/10 [00:00<?, ?it/s]
# <img src="data:image/png;base64,..." width="500">

# %% [markdown]
# # Crop - OPTIONAL

# %% [markdown]
# ### select crop region (Zzz)

# %%
o_gui = Interface(o_imars3dui=o_imars3dui,
                  mode='crop',
                  callback=o_imars3dui.saving_crop_region)
o_gui.show()
# Out:
# <span style="font-size: 20px; color=green">Please be patient!</span>
# <span style="font-size: 20px; color:blue">Check UI that popped up                 (maybe hidden behind this browser!)</span>

# %% [markdown]
# ### perform cropping

# %%
o_imars3dui.perform_cropping()
# Out:
# Running crop ...
# cropping done!

# %% [markdown]
# # Gamma filtering  (<font size=5 type="bold">Z</font><font size=4 type="bold">Z</font><font size=3 type="bold">Z</font>) - OPTIONAL

# %%
o_imars3dui.gamma_filtering()
# Out:
# Running gamma filtering ...
# Gamma filtering done in 1.69s

# %% [markdown]
# # Normalization (<font size=5 type="bold">Z</font><font size=4 type="bold">Z</font><font size=3 type="bold">Z</font>) - MANDATORY

# %%
o_imars3dui.normalization_and_display()
# Out:
# Running normalization ...
# normalization done in 1.68s
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Export data (Optional cell)

# %%
o_imars3dui.export_normalization()

# %% [markdown]
# # Beam fluctuation correction - OPTIONAL

# %% [markdown]
# ### Select a region that does not contain the sample to improve the normalization

# %%
o_gui = Interface(o_imars3dui=o_imars3dui,
                  mode='background',
                  callback=o_imars3dui.saving_beam_fluctuation_correction)
o_gui.show()

# %% [markdown]
# ### perform beam fluctuation correction

# %%
o_imars3dui.beam_fluctuation_correction()

# %% [markdown]
# # Transmission to attenuation - MANDATORY

# %%
o_imars3dui.minus_log_and_display()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Tilt correction (<font size=5 type="bold">Z</font><font size=4 type="bold">Z</font><font size=3 type="bold">Z</font>) - OPTIONAL

# %% [markdown]
# ## find 0 and 180 degrees files

# %%
o_imars3dui.find_0_180_degrees_files()

# %% [markdown]
# ## calculate tilt

# %%
o_imars3dui.calculate_tilt()

# %% [markdown]
# ## apply tilt correction

# %%
o_imars3dui.apply_tilt_and_display()

# %% [markdown]
# # Strikes removal (<font size=5 type="bold">Z</font><font size=4 type="bold">Z</font><font size=3 type="bold">Z</font>) - OPTIONAL

# %% [markdown]
# ### using imars3d - ketcham method working on 3D stack

# %%
o_imars3dui.strikes_removal()

# %% [markdown]
# # Display sinogram - OPTIONAL

# %%
o_imars3dui.display_sinogram()

# %% [markdown]
# # Rotation center (<font size=5 type="bold">Z</font><font size=4 type="bold">Z</font><font size=3 type="bold">Z</font>) - MANDATORY

# %%
o_imars3dui.rotation_center()
# Out:
# Running rotation center ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 o_imars3dui.rotation_center()
#
# File /Volumes/JeanHardDrive/git/iMars3d_notebooks/__code/imars3dui_skipped_algorithms.py:663, in Imars3dui.rotation_center(self)
#     657 print(f"Running rotation center ...")
#     658 t0 = timeit.default_timer()
#     659 self.rot_center = find_rotation_center(arrays=self.proj_mlog,
#     660                                        angles=self.rot_angles,
#     661                                        num_pairs=-1,
#     662                                        in_degrees=True,
# --> 663                                        atol_deg=self.mean_delta_angle,
#     664                                        )
#     665 t1 = timeit.default_timer()
#     666 print(f"rotation center found in {t1-t0:.2f}s")
#
# AttributeError: 'Imars3dui' object has no attribute 'mean_delta_angle'

# %% [markdown]
# # Reconstruction - MANDATORY

# %%
o_imars3dui.reconstruction_and_display()

# %% [markdown]
# # Export

# %%
o_imars3dui.export()
